# %% [markdown]
# # **DATA CLEANING.**

# %% [markdown]
# ## **Libraries.**

# %%
import numpy as np
import pandas as pd
import re
import src_functions as ft

# %% [markdown]
# ## **Dataset import.**

# %%
shark_attacks = pd.read_csv('../data/attacks.csv', encoding='unicode_escape')

shark_attacks
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %% [markdown]
# **Can see there is many NaN values in rows at the end of the table, so means there is null values in any column.**

# %% [markdown]
# ## **Cleaning.**

# %% [markdown]
# ### **Since there are many null values in the dataset in each column, we are going to eliminate all posible rows that have null values in all of it.**

# %%
shark_attacks.dropna(axis=0, inplace=True, how='all')

shark_attacks.shape
# Out:
# (8703, 24)

# %% [markdown]
# **We have gone from having about 26000 rows to having almost 9000. Now we are going to check the rows that are duplicates, and remove them.**

# %%
shark_attacks.duplicated().sum()
# Out:
# 2392

# %%
shark_attacks = shark_attacks.drop_duplicates()

shark_attacks.shape
# Out:
# (6311, 24)

# %% [markdown]
# **Now, we have about 6000 rows, with hardly any null values in many of them, and without duplicates. Let´s drop rows that have a certain number of NaN values.**

# %%
shark_attacks = ft.drop_null_rows(shark_attacks, 10)
shark_attacks.reset_index(drop = True)
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6290     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6291     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6292     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6293     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6294     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6290  Western Australia                          Roebuck Bay        Diving
# 6291  Western Australia                                  NaN  Pearl diving
# 6292     North Carolina                       Ocracoke Inlet      Swimming
# 6293                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6294   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species   \
# 0               Julie Wolfe    F  ...      White shark
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6290                   male    M  ...              NaN
# 6291                  Ahmun    M  ...              NaN
# 6292  Coast Guard personnel    M  ...              NaN
# 6293        Jules Patterson    M  ...              NaN
# 6294                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf  \
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6290       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6291  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6292   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6293                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6294                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6291  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6293  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6294  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6290  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6291  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6292  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6293  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6294  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6290       ND.0005            6.0         NaN         NaN
# 6291       ND.0004            5.0         NaN         NaN
# 6292       ND.0003            4.0         NaN         NaN
# 6293       ND.0002            3.0         NaN         NaN
# 6294       ND.0001            2.0         NaN         NaN
#
# [6295 rows x 24 columns]

# %%
shark_attacks.shape
# Out:
# (6295, 24)

# %% [markdown]
# ### **Now, we are going to transform certain columns, because there are many inconsistent values, and much of them are duplicated, or are null.**

# %%
# there are some columns that has a space in the name. Let's remove them
shark_attacks.columns = shark_attacks.columns.str.strip()

# we are going to replace the space between words in the columns by an underscore
shark_attacks = shark_attacks.rename(columns=lambda x: x.replace(' ', '_'))

shark_attacks.columns
# Out:
# Index(['Case_Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal_(Y/N)', 'Time',
#        'Species', 'Investigator_or_Source', 'pdf', 'href_formula', 'href',
#        'Case_Number.1', 'Case_Number.2', 'original_order', 'Unnamed:_22',
#        'Unnamed:_23'],
#       dtype='object')

# %% [markdown]
# ##### **'Unnamed:_22' and 'Unnamed:_23'**

# %%
# let's fill in all the null values in this columns

shark_attacks['Unnamed:_22'].isnull().sum()
# Out:
# 6294

# %% [markdown]
# ## **Export clean dataset.**

# %% [markdown]
# ### **Let's export a copy of the clean dataset for working on it for do a deep analysis.**

# %%
shark_attacks.to_csv('../data/shark_attacks_clean.csv', index = False)
